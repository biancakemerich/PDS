# %%
import numpy as np # arrays
import matplotlib.pyplot as plt # plots
plt.rcParams.update({'font.size': 14})
import IPython.display as ipd # to play signals
import sounddevice as sd
import soundfile as sf

# %%
#Importando os arquivos .wav
file_xt = r'C:\Users\Bianca\Documents\SinaisESistemas\Bianca Pereira Kemerich - Viola, Grieg, Peer Gynt.wav'
file_ht = r'C:\Users\Bianca\Documents\SinaisESistemas\Bianca Pereira Kemerich - ht.Wav'
xt, fs = sf.read(file_xt)
time_xt = np.linspace(0, (len(xt)-1)/fs, len(xt))
ht, fs = sf.read(file_ht)
time_ht = np.linspace(0, (len(ht)-1)/fs, len(ht))

# %%
ipd.Audio(xt, rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
